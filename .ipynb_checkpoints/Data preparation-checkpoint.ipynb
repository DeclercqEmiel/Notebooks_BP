# %%
import pandas as pd
import matplotlib.pylab as plt
import numpy as np

# %% [markdown]
# # Dataset exploration

# %% [markdown]
# ## Dataset #1: seaice

# %% [markdown]
# source: https://www.kaggle.com/nsidcorg/daily-sea-ice-extent-data

# %%
ice = pd.read_csv('../Datasets/seaice.csv')

# %%
ice.columns = ['Year', 'Month', 'Day', 'Extent', 'Missing', 'Source Data',
       'hemisphere']

# %%
ice
# Out:
#        Year  Month  Day  Extent  Missing  \
# 0      1978     10   26  10.231      0.0
# 1      1978     10   28  10.420      0.0
# 2      1978     10   30  10.557      0.0
# 3      1978     11    1  10.670      0.0
# 4      1978     11    3  10.777      0.0
# ...     ...    ...  ...     ...      ...
# 26349  2019      5   27  10.085      0.0
# 26350  2019      5   28  10.078      0.0
# 26351  2019      5   29  10.219      0.0
# 26352  2019      5   30  10.363      0.0
# 26353  2019      5   31  10.436      0.0
#
#                                              Source Data hemisphere
# 0       ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...      north
# 1       ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...      north
# 2       ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...      north
# 3       ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...      north
# 4       ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...      north
# ...                                                  ...        ...
# 26349  ['ftp://sidads.colorado.edu/pub/DATASETS/nsidc...      south
# 26350  ['ftp://sidads.colorado.edu/pub/DATASETS/nsidc...      south
# 26351  ['ftp://sidads.colorado.edu/pub/DATASETS/nsidc...      south
# 26352  ['ftp://sidads.colorado.edu/pub/DATASETS/nsidc...      south
# 26353  ['ftp://sidads.colorado.edu/pub/DATASETS/nsidc...      south
#
# [26354 rows x 7 columns]

# %%
plt.plot(ice[['Extent']])

# %%
ice.groupby('hemisphere').count()
# Out:
#              Year  Month    Day  Extent  Missing  Source Data
# hemisphere
# north       13177  13177  13177   13177    13177        13177
# south       13177  13177  13177   13177    13177        13177

# %%
ice.groupby('Year').count()[['Extent']]
# Out:
#       Extent
# Year
# 1978      68
# 1979     364
# 1980     366
# 1981     366
# 1982     364
# 1983     366
# 1984     366
# 1985     364
# 1986     366
# 1987     440
# 1988     708
# 1989     730
# 1990     730
# 1991     730
# 1992     732
# 1993     730
# 1994     730
# 1995     730
# 1996     732
# 1997     730
# 1998     730
# 1999     730
# 2000     732
# 2001     730
# 2002     730
# 2003     730
# 2004     732
# 2005     730
# 2006     730
# 2007     730
# 2008     732
# 2009     730
# 2010     730
# 2011     730
# 2012     732
# 2013     730
# 2014     730
# 2015     730
# 2016     732
# 2017     730
# 2018     730
# 2019     302

# %%
ice.groupby('Year').mean()[['Extent']]
# Out:
#          Extent
# Year
# 1978  12.976838
# 1979  12.019349
# 1980  11.785219
# 1981  11.776148
# 1982  12.048755
# 1983  11.852904
# 1984  11.681139
# 1985  11.810214
# 1986  11.639773
# 1987  12.149411
# 1988  11.889179
# 1989  11.696267
# 1990  11.551718
# 1991  11.647066
# 1992  11.754549
# 1993  11.671496
# 1994  11.892644
# 1995  11.604933
# 1996  11.804958
# 1997  11.528833
# 1998  11.747877
# 1999  11.726074
# 2000  11.627701
# 2001  11.636321
# 2002  11.292237
# 2003  11.683255
# 2004  11.600966
# 2005  11.300927
# 2006  11.116763
# 2007  11.080601
# 2008  11.608627
# 2009  11.490281
# 2010  11.409092
# 2011  10.992034
# 2012  11.205268
# 2013  11.710360
# 2014  11.783311
# 2015  11.489959
# 2016  10.682796
# 2017  10.570814
# 2018  10.632312
# 2019   9.243646

# %%
plt.scatter(ice.groupby('Year').mean()[['Extent']][:-1].index, ice.groupby('Year').mean()[['Extent']][:-1])

# %%
ice.groupby(['Year','hemisphere']).count().head(60)
# Out:
#                  Month  Day  Extent  Missing  Source Data
# Year hemisphere
# 1978 north          34   34      34       34           34
#      south          34   34      34       34           34
# 1979 north         182  182     182      182          182
#      south         182  182     182      182          182
# 1980 north         183  183     183      183          183
#      south         183  183     183      183          183
# 1981 north         183  183     183      183          183
#      south         183  183     183      183          183
# 1982 north         182  182     182      182          182
#      south         182  182     182      182          182
# 1983 north         183  183     183      183          183
#      south         183  183     183      183          183
# 1984 north         183  183     183      183          183
#      south         183  183     183      183          183
# 1985 north         182  182     182      182          182
#      south         182  182     182      182          182
# 1986 north         183  183     183      183          183
#      south         183  183     183      183          183
# 1987 north         220  220     220      220          220
#      south         220  220     220      220          220
# 1988 north         354  354     354      354          354
#      south         354  354     354      354          354
# 1989 north         365  365     365      365          365
#      south         365  365     365      365          365
# 1990 north         365  365     365      365          365
#      south         365  365     365      365          365
# 1991 north         365  365     365      365          365
#      south         365  365     365      365          365
# 1992 north         366  366     366      366          366
#      south         366  366     366      366          366
# 1993 north         365  365     365      365          365
#      south         365  365     365      365          365
# 1994 north         365  365     365      365          365
#      south         365  365     365      365          365
# 1995 north         365  365     365      365          365
#      south         365  365     365      365          365
# 1996 north         366  366     366      366          366
#      south         366  366     366      366          366
# 1997 north         365  365     365      365          365
#      south         365  365     365      365          365
# 1998 north         365  365     365      365          365
#      south         365  365     365      365          365
# 1999 north         365  365     365      365          365
#      south         365  365     365      365          365
# 2000 north         366  366     366      366          366
#      south         366  366     366      366          366
# 2001 north         365  365     365      365          365
#      south         365  365     365      365          365
# 2002 north         365  365     365      365          365
#      south         365  365     365      365          365
# 2003 north         365  365     365      365          365
#      south         365  365     365      365          365
# 2004 north         366  366     366      366          366
#      south         366  366     366      366          366
# 2005 north         365  365     365      365          365
#      south         365  365     365      365          365
# 2006 north         365  365     365      365          365
#      south         365  365     365      365          365
# 2007 north         365  365     365      365          365
#      south         365  365     365      365          365

# %%
plt.xlabel('Years')
plt.ylabel('Extent')
plt.plot(ice[ice['hemisphere'] == 'north'].groupby('Year').mean()[['Extent']][:-1].index, ice[ice['hemisphere'] == 'north'].groupby('Year').mean()[['Extent']][:-1],label='Northern hemisphere')
plt.plot(ice[ice['hemisphere'] == 'south'].groupby('Year').mean()[['Extent']][:-1].index, ice[ice['hemisphere'] == 'south'].groupby('Year').mean()[['Extent']][:-1],label='Southern hemisphere')
plt.legend()

# %%
plt.xlabel('Years')
plt.ylabel('Extent')
plt.scatter(ice.groupby('Year').mean()[['Extent']][:-1].index, ice.groupby('Year').mean()[['Extent']][:-1])

# %%
print('start : ' + str(ice['Year'][0]))
print('end : ' + str(ice['Year'].tail(1).iloc[0]))
# Out:
# start : 1978
# end : 2019

# %%
2019-1978
# Out:
# 41

# %% [markdown]
# ## Dataset #2: Toronto_temp

# %% [markdown]
# Source: https://www.kaggle.com/rainbowgirl/climate-data-toronto-19372018

# %%
tt = pd.read_csv('../Datasets/Toronto_temp.csv')

# %%
tt.groupby('Year').count()
# Out:
#       Date/Time  Month  Day  Mean Temp (C)  Max Temp (C)  Min Temp (C)  \
# Year
# 1937          2      2    2              2             2             2
# 1938         12     12   12             12            12            12
# 1939         12     12   12              8             8             8
# 1940         12     12   12             12            12            12
# 1941         12     12   12             12            12            12
# ...         ...    ...  ...            ...           ...           ...
# 2009         12     12   12             12            12            12
# 2010         12     12   12             12            12            12
# 2011         12     12   12             12            12            12
# 2012         12     12   12             12            12            12
# 2013          6      6    6              6             6             6
#
#       Total Rain (mm)  Total Snow (cm)  Total Precip (mm)  season
# Year
# 1937                2                2                  2       2
# 1938               12               12                 12      12
# 1939                8                8                  8      12
# 1940               12               12                 12      12
# 1941               12               12                 12      12
# ...               ...              ...                ...     ...
# 2009               12               12                 12      12
# 2010               12               12                 12      12
# 2011               12               12                 12      12
# 2012               12               12                 12      12
# 2013                6                6                  6       6
#
# [83 rows x 10 columns]

# %%
tt.groupby('Year').count()[1:-1]
# Out:
#       Date/Time  Month  Day  Mean Temp (C)  Max Temp (C)  Min Temp (C)  \
# Year
# 1938         12     12   12             12            12            12
# 1939         12     12   12              8             8             8
# 1940         12     12   12             12            12            12
# 1941         12     12   12             12            12            12
# 1942         12     12   12             12            12            12
# ...         ...    ...  ...            ...           ...           ...
# 2008         12     12   12             12            12            12
# 2009         12     12   12             12            12            12
# 2010         12     12   12             12            12            12
# 2011         12     12   12             12            12            12
# 2012         12     12   12             12            12            12
#
#       Total Rain (mm)  Total Snow (cm)  Total Precip (mm)  season
# Year
# 1938               12               12                 12      12
# 1939                8                8                  8      12
# 1940               12               12                 12      12
# 1941               12               12                 12      12
# 1942               12               12                 12      12
# ...               ...              ...                ...     ...
# 2008               12               12                 12      12
# 2009               12               12                 12      12
# 2010               12               12                 12      12
# 2011               12               12                 12      12
# 2012               12               12                 12      12
#
# [81 rows x 10 columns]

# %%
meantt = tt.groupby('Year').mean()[1:-1]['Mean Temp (C)']

# %%
plt.scatter(meantt.index, meantt)

# %%
plt.xlabel('Years')
plt.ylabel('Temperature (°C)')
plt.xticks(np.array(range(0,meantt.size,10)))
plt.scatter(meantt.index, meantt)

# %%
print('start : ' + meantt.index[0])
print('end : ' + meantt.index[-1])
# Out:
# start : 1938
# end : 2012

# %% [markdown]
# ## Dataset #3: seaice2

# %% [markdown]
# Completer version of dataset #1
#
# source: https://nsidc.org/arcticseaicenews/sea-ice-tools/

# %%
ice2 = pd.read_csv('../Datasets/seaice2.csv')

# %%
ice2_mean = ice2.mean()[1:-2]
ice2_mean
# Out:
# 1978    12.487000
# 1979    12.319560
# 1980    12.334148
# 1981    12.135486
# 1982    12.439445
# 1983    12.335896
# 1984    11.912601
# 1985    11.986599
# 1986    12.208224
# 1987    11.397227
# 1988    12.093169
# 1989    11.966855
# 1990    11.693841
# 1991    11.749258
# 1992    12.110481
# 1993    11.923052
# 1994    12.011318
# 1995    11.415110
# 1996    11.840787
# 1997    11.667614
# 1998    11.757381
# 1999    11.691466
# 2000    11.508175
# 2001    11.600016
# 2002    11.362866
# 2003    11.397222
# 2004    11.240434
# 2005    10.906975
# 2006    10.772614
# 2007    10.474096
# 2008    10.977847
# 2009    10.931970
# 2010    10.711392
# 2011    10.483496
# 2012    10.406098
# 2013    10.897115
# 2014    10.790496
# 2015    10.565816
# 2016    10.163478
# 2017    10.392701
# 2018    10.355041
# 2019    10.200984
# 2020    10.062228
# dtype: float64

# %%
ice2_mean.index = ice2_mean.index.values.astype(int)

# %%
plt.scatter(ice2_mean.index,ice2_mean)
plt.xlabel('Years')
plt.ylabel('Extent')
# Out:
# Text(0, 0.5, 'Extent')

# %%
ice2['2018']
# Out:
# 0      12.484
# 1      12.600
# 2      12.634
# 3      12.724
# 4      12.834
#         ...
# 361    12.325
# 362    12.344
# 363    12.523
# 364    12.569
# 365    12.621
# Name: 2018, Length: 366, dtype: float64

# %%
pd.concat([ice2['2016'],ice2['2017'],ice2['2018'],ice2['2019']]).reset_index()[0]
# Out:
# 0       12.721
# 1       12.806
# 2       12.790
# 3       12.829
# 4       12.874
#          ...
# 1459    12.721
# 1460    12.712
# 1461    12.780
# 1462    12.858
# 1463    12.889
# Name: 0, Length: 1464, dtype: float64

# %%
ice2[['2018']].append(ice2[['2019']])
# Out:
#        2018    2019
# 0    12.484     NaN
# 1    12.600     NaN
# 2    12.634     NaN
# 3    12.724     NaN
# 4    12.834     NaN
# ..      ...     ...
# 361     NaN  12.721
# 362     NaN  12.712
# 363     NaN  12.780
# 364     NaN  12.858
# 365     NaN  12.889
#
# [732 rows x 2 columns]

# %%
df2_tidy = df2_melted.rename(columns = {'variable': 'Year', 'value': 'Income'}, inplace = False)

# %%
ice2.rename(columns={'Unnamed: 0' : 'Month', 'Unnamed: 1' : 'Day'}, inplace = True)

# %%
ice2.drop([' ','1981-2010'],axis=1,inplace=True)

# %%
values = ice2.values

# %%
i = 0
for row in values :
    if type(row[0]) != str :
        values[i][0] = month
    else:
        month = row[0]
    i = i +1

# %%
ice2.columns.values
# Out:
# array(['Month', 'Day', '1978', '1979', '1980', '1981', '1982', '1983',
#        '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991',
#        '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999',
#        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020'], dtype=object)

# %%
ice2_clean = pd.DataFrame(values)

# %%
ice2_clean.columns = ice2.columns.values

# %%
ice2_clean.head(5)
# Out:
#      Month Day 1978    1979    1980    1981    1982    1983    1984    1985  \
# 0  January   1  NaN     NaN    14.2  14.256     NaN  14.253     NaN     NaN
# 1  January   2  NaN  14.997     NaN     NaN  14.479     NaN  14.103  14.045
# 2  January   3  NaN     NaN  14.302  14.456     NaN  14.306     NaN     NaN
# 3  January   4  NaN  14.922     NaN     NaN  14.642     NaN  14.237   14.24
# 4  January   5  NaN     NaN  14.414  14.435     NaN  14.494     NaN     NaN
#
#    ...    2011    2012    2013    2014    2015    2016    2017    2018  \
# 0  ...  12.896  13.353  12.959  13.011  13.073  12.721  12.643  12.484
# 1  ...  12.915  13.421  12.961  13.103  13.125  12.806  12.644    12.6
# 2  ...  12.926  13.379  13.012  13.116  13.112   12.79  12.713  12.634
# 3  ...  13.051  13.414  13.045  13.219  13.051  12.829  12.954  12.724
# 4  ...  13.176  13.417  13.065  13.148  13.115  12.874  12.956  12.834
#
#      2019    2020
# 0  12.934  13.102
# 1  12.992  13.075
# 2   12.98  13.176
# 3  13.045  13.187
# 4  13.147  13.123
#
# [5 rows x 45 columns]

# %%
ice2_clean.groupby('Month').mean()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-354-6c3669732418> in <module>
# ----> 1 ice2_clean.groupby('Month').mean()
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, *args, **kwargs)
#    1230         nv.validate_groupby_func("mean", args, kwargs, ["numeric_only"])
#    1231         return self._cython_agg_general(
# -> 1232             "mean", alt=lambda x, axis: Series(x).mean(**kwargs), **kwargs
#    1233         )
#    1234
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1002     ) -> DataFrame:
#    1003         agg_blocks, agg_items = self._cython_agg_blocks(
# -> 1004             how, alt=alt, numeric_only=numeric_only, min_count=min_count
#    1005         )
#    1006         return self._wrap_agged_blocks(agg_blocks, items=agg_items)
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#    1103
#    1104         if not (agg_blocks or split_frames):
# -> 1105             raise DataError("No numeric types to aggregate")
#    1106
#    1107         if split_items:
#
# DataError: No numeric types to aggregate

# %%
plt.plot(pd.concat([ice2['2016'],ice2['2017'],ice2['2018'],ice2['2019']]).reset_index()[0])

# %% [markdown]
# # Dataset Combination

# %%
2012-1978
# Out:
# 34

# %% [raw]
# timespan of 34 years with combined dataset
