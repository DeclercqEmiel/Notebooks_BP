# %%
import pandas as pd
import matplotlib.pylab as plt
import numpy as np

# %% [markdown]
# # Dataset exploration

# %% [markdown]
# ## Dataset #1: seaice

# %% [markdown]
# source: https://www.kaggle.com/nsidcorg/daily-sea-ice-extent-data

# %%
ice = pd.read_csv('./data/seaice.csv')

# %%
ice.columns = ['Year', 'Month', 'Day', 'Extent', 'Missing', 'Source Data',
       'hemisphere']

# %%
ice
# Out:
#        Year  Month  Day  Extent  Missing  \
# 0      1978     10   26  10.231      0.0
# 1      1978     10   28  10.420      0.0
# 2      1978     10   30  10.557      0.0
# 3      1978     11    1  10.670      0.0
# 4      1978     11    3  10.777      0.0
# ...     ...    ...  ...     ...      ...
# 26349  2019      5   27  10.085      0.0
# 26350  2019      5   28  10.078      0.0
# 26351  2019      5   29  10.219      0.0
# 26352  2019      5   30  10.363      0.0
# 26353  2019      5   31  10.436      0.0
#
#                                              Source Data hemisphere
# 0       ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...      north
# 1       ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...      north
# 2       ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...      north
# 3       ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...      north
# 4       ['ftp://sidads.colorado.edu/pub/DATASETS/nsid...      north
# ...                                                  ...        ...
# 26349  ['ftp://sidads.colorado.edu/pub/DATASETS/nsidc...      south
# 26350  ['ftp://sidads.colorado.edu/pub/DATASETS/nsidc...      south
# 26351  ['ftp://sidads.colorado.edu/pub/DATASETS/nsidc...      south
# 26352  ['ftp://sidads.colorado.edu/pub/DATASETS/nsidc...      south
# 26353  ['ftp://sidads.colorado.edu/pub/DATASETS/nsidc...      south
#
# [26354 rows x 7 columns]

# %%
plt.plot(ice[['Extent']])

# %%
ice.groupby('hemisphere').count()
# Out:
#              Year  Month    Day  Extent  Missing  Source Data
# hemisphere
# north       13177  13177  13177   13177    13177        13177
# south       13177  13177  13177   13177    13177        13177

# %%
ice.groupby('Year').count()[['Extent']]
# Out:
#       Extent
# Year
# 1978      68
# 1979     364
# 1980     366
# 1981     366
# 1982     364
# 1983     366
# 1984     366
# 1985     364
# 1986     366
# 1987     440
# 1988     708
# 1989     730
# 1990     730
# 1991     730
# 1992     732
# 1993     730
# 1994     730
# 1995     730
# 1996     732
# 1997     730
# 1998     730
# 1999     730
# 2000     732
# 2001     730
# 2002     730
# 2003     730
# 2004     732
# 2005     730
# 2006     730
# 2007     730
# 2008     732
# 2009     730
# 2010     730
# 2011     730
# 2012     732
# 2013     730
# 2014     730
# 2015     730
# 2016     732
# 2017     730
# 2018     730
# 2019     302

# %%
ice.groupby('Year').mean()[['Extent']]
# Out:
#          Extent
# Year
# 1978  12.976838
# 1979  12.019349
# 1980  11.785219
# 1981  11.776148
# 1982  12.048755
# 1983  11.852904
# 1984  11.681139
# 1985  11.810214
# 1986  11.639773
# 1987  12.149411
# 1988  11.889179
# 1989  11.696267
# 1990  11.551718
# 1991  11.647066
# 1992  11.754549
# 1993  11.671496
# 1994  11.892644
# 1995  11.604933
# 1996  11.804958
# 1997  11.528833
# 1998  11.747877
# 1999  11.726074
# 2000  11.627701
# 2001  11.636321
# 2002  11.292237
# 2003  11.683255
# 2004  11.600966
# 2005  11.300927
# 2006  11.116763
# 2007  11.080601
# 2008  11.608627
# 2009  11.490281
# 2010  11.409092
# 2011  10.992034
# 2012  11.205268
# 2013  11.710360
# 2014  11.783311
# 2015  11.489959
# 2016  10.682796
# 2017  10.570814
# 2018  10.632312
# 2019   9.243646

# %%
plt.scatter(ice.groupby('Year').mean()[['Extent']][:-1].index, ice.groupby('Year').mean()[['Extent']][:-1])

# %%
ice.groupby(['Year','hemisphere']).count().head(60)
# Out:
#                  Month  Day  Extent  Missing  Source Data
# Year hemisphere
# 1978 north          34   34      34       34           34
#      south          34   34      34       34           34
# 1979 north         182  182     182      182          182
#      south         182  182     182      182          182
# 1980 north         183  183     183      183          183
#      south         183  183     183      183          183
# 1981 north         183  183     183      183          183
#      south         183  183     183      183          183
# 1982 north         182  182     182      182          182
#      south         182  182     182      182          182
# 1983 north         183  183     183      183          183
#      south         183  183     183      183          183
# 1984 north         183  183     183      183          183
#      south         183  183     183      183          183
# 1985 north         182  182     182      182          182
#      south         182  182     182      182          182
# 1986 north         183  183     183      183          183
#      south         183  183     183      183          183
# 1987 north         220  220     220      220          220
#      south         220  220     220      220          220
# 1988 north         354  354     354      354          354
#      south         354  354     354      354          354
# 1989 north         365  365     365      365          365
#      south         365  365     365      365          365
# 1990 north         365  365     365      365          365
#      south         365  365     365      365          365
# 1991 north         365  365     365      365          365
#      south         365  365     365      365          365
# 1992 north         366  366     366      366          366
#      south         366  366     366      366          366
# 1993 north         365  365     365      365          365
#      south         365  365     365      365          365
# 1994 north         365  365     365      365          365
#      south         365  365     365      365          365
# 1995 north         365  365     365      365          365
#      south         365  365     365      365          365
# 1996 north         366  366     366      366          366
#      south         366  366     366      366          366
# 1997 north         365  365     365      365          365
#      south         365  365     365      365          365
# 1998 north         365  365     365      365          365
#      south         365  365     365      365          365
# 1999 north         365  365     365      365          365
#      south         365  365     365      365          365
# 2000 north         366  366     366      366          366
#      south         366  366     366      366          366
# 2001 north         365  365     365      365          365
#      south         365  365     365      365          365
# 2002 north         365  365     365      365          365
#      south         365  365     365      365          365
# 2003 north         365  365     365      365          365
#      south         365  365     365      365          365
# 2004 north         366  366     366      366          366
#      south         366  366     366      366          366
# 2005 north         365  365     365      365          365
#      south         365  365     365      365          365
# 2006 north         365  365     365      365          365
#      south         365  365     365      365          365
# 2007 north         365  365     365      365          365
#      south         365  365     365      365          365

# %%
plt.xlabel('Years')
plt.ylabel('Extent')
plt.plot(ice[ice['hemisphere'] == 'north'].groupby('Year').mean()[['Extent']][:-1].index, ice[ice['hemisphere'] == 'north'].groupby('Year').mean()[['Extent']][:-1],label='Northern hemisphere')
plt.plot(ice[ice['hemisphere'] == 'south'].groupby('Year').mean()[['Extent']][:-1].index, ice[ice['hemisphere'] == 'south'].groupby('Year').mean()[['Extent']][:-1],label='Southern hemisphere')
plt.legend()

# %%
plt.xlabel('Years')
plt.ylabel('Extent')
plt.scatter(ice.groupby('Year').mean()[['Extent']][:-1].index, ice.groupby('Year').mean()[['Extent']][:-1])

# %%
print('start : ' + str(ice['Year'][0]))
print('end : ' + str(ice['Year'].tail(1).iloc[0]))
# Out:
# start : 1978
# end : 2019

# %%
2019-1978
# Out:
# 41

# %% [markdown]
# ## Dataset #2: Toronto_temp

# %% [markdown]
# Source: https://www.kaggle.com/rainbowgirl/climate-data-toronto-19372018

# %%
tt = pd.read_csv('./data/Toronto_temp.csv')

# %%
tt.groupby('Year').count().index
# Out:
# Index(['1937', '1938', '1939', '1940', '1941', '1942', '1943', '1944', '1945',
#        '1946', '1947', '1948', '1949', '1950', '1951', '1952', '1953', '1954',
#        '1955', '1956', '1957', '1958', '1959', '1960', '1961', '1962', '1963',
#        '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972',
#        '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981',
#        '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990',
#        '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999',
#        '2,013', '2,014', '2,015', '2,016', '2,017', '2,018', '2000', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013'],
#       dtype='object', name='Year')

# %%
tt.groupby('Year').count()[1:-1]
# Out:
#       Date/Time  Month  Day  Mean Temp (C)  Max Temp (C)  Min Temp (C)  \
# Year
# 1938         12     12   12             12            12            12
# 1939         12     12   12              8             8             8
# 1940         12     12   12             12            12            12
# 1941         12     12   12             12            12            12
# 1942         12     12   12             12            12            12
# ...         ...    ...  ...            ...           ...           ...
# 2008         12     12   12             12            12            12
# 2009         12     12   12             12            12            12
# 2010         12     12   12             12            12            12
# 2011         12     12   12             12            12            12
# 2012         12     12   12             12            12            12
#
#       Total Rain (mm)  Total Snow (cm)  Total Precip (mm)  season
# Year
# 1938               12               12                 12      12
# 1939                8                8                  8      12
# 1940               12               12                 12      12
# 1941               12               12                 12      12
# 1942               12               12                 12      12
# ...               ...              ...                ...     ...
# 2008               12               12                 12      12
# 2009               12               12                 12      12
# 2010               12               12                 12      12
# 2011               12               12                 12      12
# 2012               12               12                 12      12
#
# [81 rows x 10 columns]

# %%
meantt = tt.groupby('Year').mean()[1:-1]['Mean Temp (C)']

# %%
meantt.index
# Out:
# Index(['1938', '1939', '1940', '1941', '1942', '1943', '1944', '1945', '1946',
#        '1947', '1948', '1949', '1950', '1951', '1952', '1953', '1954', '1955',
#        '1956', '1957', '1958', '1959', '1960', '1961', '1962', '1963', '1964',
#        '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973',
#        '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982',
#        '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991',
#        '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2,013',
#        '2,014', '2,015', '2,016', '2,017', '2,018', '2000', '2001', '2002',
#        '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
#        '2012'],
#       dtype='object', name='Year')

# %%
meantt.rename({'2,013':'2013',
              '2,014':'2014',
              '2,015':'2015',
              '2,016':'2016',
              '2,017':'2017',
              '2,018':'2018'},inplace=True)

# %%
meantt.sort_index(inplace=True)

# %%
plt.scatter(meantt.index, meantt)

# %%
plt.xlabel('Years')
plt.ylabel('Temperature (°C)')
plt.xticks(np.array(range(0,meantt.size,10)))
plt.scatter(meantt.index, meantt)

# %%
meantt
# Out:
# Year
# 1938     8.066667
# 1939     7.812500
# 1940     6.050000
# 1941     8.041667
# 1942     7.458333
#           ...
# 2014     7.539726
# 2015     8.679452
# 2016    10.117486
# 2017     9.354396
# 2018    10.541139
# Name: Mean Temp (C), Length: 81, dtype: float64

# %%
print('start : ' + meantt.index[0])
print('end : ' + meantt.index[-1])
# Out:
# start : 1938
# end : 2018

# %%
new_row = pd.Series({'Mean Temp (C)' : 0.555556, 'Year': '2,018', 'Month':'12'})
tt = tt.append(new_row, ignore_index=True)

# %%
mean_temp_monthly = tt[['Year','Month','Mean Temp (C)']].set_index(['Year','Month']).rename({'2,013':'2013',
              '2,014':'2014',
              '2,015':'2015',
              '2,016':'2016',
              '2,017':'2017',
              '2,018':'2018'}).sort_index()

# %%
mean_temp_monthly = mean_temp_monthly.groupby(['Year','Month']).mean()

# %%
mean_temp_monthly = mean_temp_monthly[mean_temp_monthly.index.get_level_values(0).astype(int) >= 1979 ]

# %%
mean_temp_monthly
# Out:
#             Mean Temp (C)
# Year Month
# 1979 1          -7.700000
#      2         -10.800000
#      3           1.600000
#      4           5.300000
#      5          11.400000
# ...                   ...
# 2018 8          23.258065
#      9          19.275862
#      10          9.200000
#      11          3.857143
#      12          0.555556
#
# [480 rows x 1 columns]

# %% [markdown]
# ## Dataset #3: seaice2

# %% [markdown]
# Completer version of dataset #1
#
# source: https://nsidc.org/arcticseaicenews/sea-ice-tools/

# %%
ice2 = pd.read_csv('./data/seaice2.csv')
ice2
# Out:
#     Unnamed: 0  Unnamed: 1    1978    1979    1980    1981    1982    1983  \
# 0      January           1     NaN     NaN  14.200  14.256     NaN  14.253
# 1          NaN           2     NaN  14.997     NaN     NaN  14.479     NaN
# 2          NaN           3     NaN     NaN  14.302  14.456     NaN  14.306
# 3          NaN           4     NaN  14.922     NaN     NaN  14.642     NaN
# 4          NaN           5     NaN     NaN  14.414  14.435     NaN  14.494
# ..         ...         ...     ...     ...     ...     ...     ...     ...
# 361        NaN          27  14.383     NaN     NaN  13.953     NaN  13.664
# 362        NaN          28     NaN  14.101  14.172     NaN  14.144     NaN
# 363        NaN          29  14.500     NaN     NaN  14.128     NaN  13.855
# 364        NaN          30     NaN  14.092  14.093     NaN  14.159     NaN
# 365        NaN          31  14.585     NaN     NaN  14.224     NaN  13.907
#
#        1984    1985  ...    2013    2014    2015    2016    2017    2018  \
# 0       NaN     NaN  ...  12.959  13.011  13.073  12.721  12.643  12.484
# 1    14.103  14.045  ...  12.961  13.103  13.125  12.806  12.644  12.600
# 2       NaN     NaN  ...  13.012  13.116  13.112  12.790  12.713  12.634
# 3    14.237  14.240  ...  13.045  13.219  13.051  12.829  12.954  12.724
# 4       NaN     NaN  ...  13.065  13.148  13.115  12.874  12.956  12.834
# ..      ...     ...  ...     ...     ...     ...     ...     ...     ...
# 361  13.394     NaN  ...  12.693  12.967  12.680  12.291  12.291  12.325
# 362     NaN  13.571  ...  12.870  12.930  12.745  12.484  12.235  12.344
# 363  13.494     NaN  ...  12.897  12.936  12.762  12.525  12.223  12.523
# 364     NaN  13.701  ...  12.804  13.038  12.800  12.617  12.273  12.569
# 365  13.789     NaN  ...  12.826  13.046  12.735  12.553  12.397  12.621
#
#        2019    2020      1981-2010
# 0    12.934  13.102 NaN     13.778
# 1    12.992  13.075 NaN     13.842
# 2    12.980  13.176 NaN     13.891
# 3    13.045  13.187 NaN     13.930
# 4    13.147  13.123 NaN     13.978
# ..      ...     ...  ..        ...
# 361  12.721     NaN NaN     13.437
# 362  12.712     NaN NaN     13.479
# 363  12.780     NaN NaN     13.528
# 364  12.858     NaN NaN     13.578
# 365  12.889     NaN NaN     13.624
#
# [366 rows x 47 columns]

# %%
ice2_mean = ice2.mean()[1:-2]
ice2_mean
# Out:
# 1978    12.487000
# 1979    12.319560
# 1980    12.334148
# 1981    12.135486
# 1982    12.439445
# 1983    12.335896
# 1984    11.912601
# 1985    11.986599
# 1986    12.208224
# 1987    11.397227
# 1988    12.093169
# 1989    11.966855
# 1990    11.693841
# 1991    11.749258
# 1992    12.110481
# 1993    11.923052
# 1994    12.011318
# 1995    11.415110
# 1996    11.840787
# 1997    11.667614
# 1998    11.757381
# 1999    11.691466
# 2000    11.508175
# 2001    11.600016
# 2002    11.362866
# 2003    11.397222
# 2004    11.240434
# 2005    10.906975
# 2006    10.772614
# 2007    10.474096
# 2008    10.977847
# 2009    10.931970
# 2010    10.711392
# 2011    10.483496
# 2012    10.406098
# 2013    10.897115
# 2014    10.790496
# 2015    10.565816
# 2016    10.163478
# 2017    10.392701
# 2018    10.355041
# 2019    10.200984
# 2020    10.062228
# dtype: float64

# %%
ice2_mean.index = ice2_mean.index.values.astype(int)

# %%
plt.scatter(ice2_mean.index,ice2_mean)
plt.xlabel('Years')
plt.ylabel('Extent')
# Out:
# Text(0, 0.5, 'Extent')

# %%
ice2['2018']
# Out:
# 0      12.484
# 1      12.600
# 2      12.634
# 3      12.724
# 4      12.834
#         ...
# 361    12.325
# 362    12.344
# 363    12.523
# 364    12.569
# 365    12.621
# Name: 2018, Length: 366, dtype: float64

# %%
pd.concat([ice2['2016'],ice2['2017'],ice2['2018'],ice2['2019']]).reset_index()[0]
# Out:
# 0       12.721
# 1       12.806
# 2       12.790
# 3       12.829
# 4       12.874
#          ...
# 1459    12.721
# 1460    12.712
# 1461    12.780
# 1462    12.858
# 1463    12.889
# Name: 0, Length: 1464, dtype: float64

# %%
ice2[['2018']].append(ice2[['2019']])
# Out:
#        2018    2019
# 0    12.484     NaN
# 1    12.600     NaN
# 2    12.634     NaN
# 3    12.724     NaN
# 4    12.834     NaN
# ..      ...     ...
# 361     NaN  12.721
# 362     NaN  12.712
# 363     NaN  12.780
# 364     NaN  12.858
# 365     NaN  12.889
#
# [732 rows x 2 columns]

# %%
ice2.rename(columns={'Unnamed: 0' : 'Month', 'Unnamed: 1' : 'Day'}, inplace = True)

# %%
ice2.drop([' ','1981-2010','Day','1978','2020'],axis=1,inplace=True)

# %%
values = ice2.values

# %%
i = 0
for row in values :
    if type(row[0]) != str :
        values[i][0] = month
    else:
        month = row[0]
    i = i +1

# %%
ice2.columns.values
# Out:
# array(['Month', '1979', '1980', '1981', '1982', '1983', '1984', '1985',
#        '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993',
#        '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        '2018', '2019'], dtype=object)

# %%
ice2_clean = pd.DataFrame(values)

# %%
ice2_clean.columns = ice2.columns.values

# %%
ice2_clean.head(5)
# Out:
#      Month    1979    1980    1981    1982    1983    1984    1985    1986  \
# 0  January     NaN    14.2  14.256     NaN  14.253     NaN     NaN  14.036
# 1  January  14.997     NaN     NaN  14.479     NaN  14.103  14.045     NaN
# 2  January     NaN  14.302  14.456     NaN  14.306     NaN     NaN  14.292
# 3  January  14.922     NaN     NaN  14.642     NaN  14.237   14.24     NaN
# 4  January     NaN  14.414  14.435     NaN  14.494     NaN     NaN  14.489
#
#      1987  ...    2010    2011    2012    2013    2014    2015    2016  \
# 0     NaN  ...  13.205  12.896  13.353  12.959  13.011  13.073  12.721
# 1  14.305  ...  13.232  12.915  13.421  12.961  13.103  13.125  12.806
# 2     NaN  ...  13.254  12.926  13.379  13.012  13.116  13.112   12.79
# 3  14.417  ...  13.236  13.051  13.414  13.045  13.219  13.051  12.829
# 4     NaN  ...  13.337  13.176  13.417  13.065  13.148  13.115  12.874
#
#      2017    2018    2019
# 0  12.643  12.484  12.934
# 1  12.644    12.6  12.992
# 2  12.713  12.634   12.98
# 3  12.954  12.724  13.045
# 4  12.956  12.834  13.147
#
# [5 rows x 42 columns]

# %%
ice2_monthly_mean = ice2_clean.set_index('Month').astype(float).groupby('Month',sort=False).mean()
ice2_monthly_mean
# Out:
#                 1979       1980       1981       1982       1983       1984  \
# Month
# January    15.414000  14.861875  14.909688  15.176733  14.942437  14.473267
# February   16.175286  15.955143  15.604071  15.973500  16.006143  15.298933
# March      16.341938  16.041313  15.631533  16.043875  16.085267  15.584200
# April      15.446800  15.429067  15.009933  15.466000  15.172067  15.014467
# May        13.856867  13.792600  13.801625  13.973200  13.491312  13.576687
# June       12.530000  12.204600  12.429733  12.476067  12.295667  12.151667
# July       10.311250  10.100062  10.271000  10.367063  10.570267   9.977533
# August      8.041067   7.984267   7.844313   8.139533   8.185875   7.771062
# September   7.051133   7.667067   7.138467   7.301733   7.394600   6.805200
# October     8.747938   9.182750   8.856267   9.421063   9.334067   8.560600
# November   10.943067  11.382867  10.929000  11.627467  11.461000  10.841533
# December   13.336267  13.592933  13.341125  13.641800  13.298438  12.989438
#
#                 1985       1986       1987       1988  ...       2010  \
# Month                                                  ...
# January    14.724867  14.889625  14.969800  15.090474  ...  13.739065
# February   15.465714  15.784857  16.050143  15.583379  ...  14.581429
# March      15.885938  15.909467  15.815937  15.957226  ...  15.136710
# April      15.356533  15.058800  15.210867  15.123333  ...  14.658733
# May        14.073400  13.379563  13.742933  13.560871  ...  12.866097
# June       12.219067  11.975933  12.485667  11.943433  ...  10.585100
# July        9.744563  10.146467  10.332563   9.808677  ...   8.074677
# August      7.401867   7.979563   7.499905   7.891581  ...   5.874903
# September   6.697667   7.410667   7.278700   7.369000  ...   4.865067
# October     8.545938   9.483933   9.048774   9.135032  ...   6.983903
# November   11.024533  11.453267  11.224033  11.330833  ...   9.613967
# December   13.049933  13.222437  12.540500  13.625548  ...  11.830839
#
#                 2011       2012       2013       2014       2015       2016  \
# Month
# January    13.463968  13.729419  13.702645  13.647484  13.602323  13.456774
# February   14.363036  14.553345  14.723536  14.417571  14.400643  14.202724
# March      14.546516  15.196258  15.032032  14.757516  14.370516  14.399935
# April      14.107800  14.625767  14.298733  14.087867  13.893167  13.681267
# May        12.680774  13.011806  12.997258  12.700710  12.468097  11.924419
# June       10.748667  10.674533  11.360133  11.032600  10.878900  10.412900
# July        7.724387   7.671774   8.131677   8.108452   8.377871   7.937548
# August      5.502452   4.723290   6.013516   6.077871   5.598742   5.370548
# September   4.561333   3.565600   5.208267   5.219933   4.615767   4.528500
# October     6.464548   5.885871   7.454839   7.232452   6.966226   6.081645
# November    9.771800   9.387967   9.939033  10.114600   9.846167   8.657833
# December   12.153581  12.006387  12.184258  12.352581  12.044774  11.459419
#
#                 2017       2018       2019
# Month
# January    13.190129  13.077355  13.567226
# February   14.119429  13.967250  14.393679
# March      14.290065  14.297581  14.573645
# April      13.753467  13.696067  13.434433
# May        12.630452  12.232032  12.185903
# June       10.756400  10.777500  10.593600
# July        7.939355   8.268097   7.589323
# August      5.480645   5.614806   5.026323
# September   4.821900   4.785233   4.363900
# October     6.767129   6.134097   5.734903
# November    9.492833   9.823133   9.352833
# December   11.742677  11.861484  11.903097
#
# [12 rows x 41 columns]

# %%
ice2_monthly_mean.T.stack().index.get_level_values(0)
# Out:
# Index(['1979', '1979', '1979', '1979', '1979', '1979', '1979', '1979', '1979',
#        '1979',
#        ...
#        '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019',
#        '2019'],
#       dtype='object', length=492)

# %%
ice2_monthly_mean.T.stack().reset_index(level=['Month']).drop(columns=['Month'])
# Out:
#               0
# 1979  15.414000
# 1979  16.175286
# 1979  16.341938
# 1979  15.446800
# 1979  13.856867
# ...         ...
# 2019   5.026323
# 2019   4.363900
# 2019   5.734903
# 2019   9.352833
# 2019  11.903097
#
# [492 rows x 1 columns]

# %%
ice2_monthly_mean_chron = ice2_monthly_mean.T.stack().reset_index(level=['Month']).drop(columns=['Month'])

# %%
ice2.columns.size
# Out:
# 42

# %%
# 1
plt.plot(ice2_monthly_mean_chron)
plt.xticks(np.array(range(0,42,10)))
# Out:
# ([<matplotlib.axis.XTick at 0x2234b9cce48>,
#   <matplotlib.axis.XTick at 0x2234b9cce08>,
#   <matplotlib.axis.XTick at 0x2234b9ef2c8>,
#   <matplotlib.axis.XTick at 0x2234b9f09c8>,
#   <matplotlib.axis.XTick at 0x2234b9f2088>],
#  <a list of 5 Text major ticklabel objects>)

# %%
# 2
plt.plot(ice2_monthly_mean_chron.values)
plt.xticks(np.array(range(0,500,75)))
# Out:
# ([<matplotlib.axis.XTick at 0x2234ba25488>,
#   <matplotlib.axis.XTick at 0x2234ba25448>,
#   <matplotlib.axis.XTick at 0x2234ba1fc08>,
#   <matplotlib.axis.XTick at 0x2234ba48608>,
#   <matplotlib.axis.XTick at 0x2234ba48c88>,
#   <matplotlib.axis.XTick at 0x2234ba4b508>,
#   <matplotlib.axis.XTick at 0x2234ba4b8c8>],
#  <a list of 7 Text major ticklabel objects>)

# %%
# why diff between 1 and 2???

# %%
np.unique(ice2_monthly_mean_chron.index.values).size*12
# Out:
# 492

# %%
print('from ' + ice2_monthly_mean_chron.index.values[0] + ' until ' + ice2_monthly_mean_chron.index.values[-1])
# Out:
# from 1979 until 2019

# %%
2019-1979
# Out:
# 40

# %%
ice2_monthly_mean_chron = ice2_monthly_mean.T.stack().reset_index(level=['Month']).drop(columns=['Month'])

# %% [markdown]
# # Dataset Combination

# %%
ice2_monthly_mean_chron_cut = ice2_monthly_mean_chron[:-12]
ice2_monthly_mean_chron
# Out:
#               0
# 1979  15.414000
# 1979  16.175286
# 1979  16.341938
# 1979  15.446800
# 1979  13.856867
# ...         ...
# 2019   5.026323
# 2019   4.363900
# 2019   5.734903
# 2019   9.352833
# 2019  11.903097
#
# [492 rows x 1 columns]

# %%
ice2_monthly_mean_chron_cut
# Out:
#               0
# 1979  15.414000
# 1979  16.175286
# 1979  16.341938
# 1979  15.446800
# 1979  13.856867
# ...         ...
# 2018   5.614806
# 2018   4.785233
# 2018   6.134097
# 2018   9.823133
# 2018  11.861484
#
# [480 rows x 1 columns]

# %%
mean_temp_monthly
# Out:
#             Mean Temp (C)
# Year Month
# 1979 1          -7.700000
#      2         -10.800000
#      3           1.600000
#      4           5.300000
#      5          11.400000
# ...                   ...
# 2018 8          23.258065
#      9          19.275862
#      10          9.200000
#      11          3.857143
#      12          0.555556
#
# [480 rows x 1 columns]

# %%
combined = mean_temp_monthly
combined['ice_extent'] = ice2_monthly_mean_chron_cut.values

# %%
combined
# Out:
#             Mean Temp (C)  ice_extent
# Year Month
# 1979 1          -7.700000   15.414000
#      2         -10.800000   16.175286
#      3           1.600000   16.341938
#      4           5.300000   15.446800
#      5          11.400000   13.856867
# ...                   ...         ...
# 2018 8          23.258065    5.614806
#      9          19.275862    4.785233
#      10          9.200000    6.134097
#      11          3.857143    9.823133
#      12          0.555556   11.861484
#
# [480 rows x 2 columns]

# %%
combined.rename(columns={'Mean Temp (C)': 'mean_temp'}, inplace=True)

# %%
dataframe_monthly = combined
dataframe_monthly
# Out:
#             mean_temp  ice_extent
# Year Month
# 1979 1      -7.700000   15.414000
#      2     -10.800000   16.175286
#      3       1.600000   16.341938
#      4       5.300000   15.446800
#      5      11.400000   13.856867
# ...               ...         ...
# 2018 8      23.258065    5.614806
#      9      19.275862    4.785233
#      10      9.200000    6.134097
#      11      3.857143    9.823133
#      12      0.555556   11.861484
#
# [480 rows x 2 columns]

# %%
dataframe_monthly[['mean_temp']]
# Out:
#             mean_temp
# Year Month
# 1979 1      -7.700000
#      2     -10.800000
#      3       1.600000
#      4       5.300000
#      5      11.400000
# ...               ...
# 2018 8      23.258065
#      9      19.275862
#      10      9.200000
#      11      3.857143
#      12      0.555556
#
# [480 rows x 1 columns]

# %%
plt.plot(dataframe_monthly[['mean_temp']].values[-24:],label='temp')
plt.plot(dataframe_monthly[['ice_extent']].values[-24:])
plt.legend()

# %%
dataframe_yearly = combined.groupby('Year').mean()
dataframe_yearly
# Out:
#       mean_temp  ice_extent
# Year
# 1979   6.841667   12.349634
# 1980   6.625000   12.349545
# 1981   7.141667   12.147230
# 1982   6.816667   12.467336
# 1983   7.766667   12.353095
# 1984   7.291667   11.920382
# 1985   7.200000   12.015835
# 1986   7.533333   12.224548
# 1987   8.516667   12.183318
# 1988   7.841667   12.201616
# 1989   7.016667   11.986788
# 1990   8.716667   11.716385
# 1991   8.883333   11.770302
# 1992   7.025000   12.121065
# 1993   7.175000   11.945254
# 1994   7.341667   12.032209
# 1995   7.783333   11.437963
# 1996   7.150000   11.850327
# 1997   7.558333   11.689949
# 1998  10.133333   11.780257
# 1999   9.458333   11.712603
# 2000   8.250000   11.518993
# 2001   9.641667   11.621888
# 2002   9.416667   11.385820
# 2003   7.908333   11.419148
# 2004   8.233333   11.251586
# 2005   9.016667   10.927786
# 2006   9.700000   10.793886
# 2007   8.908333   10.499133
# 2008   8.225000   10.990294
# 2009   7.975000   10.955518
# 2010   9.541667   10.734207
# 2011   9.091667   10.507405
# 2012  10.500000   10.419335
# 2013   8.591180   10.920494
# 2014   7.451478   10.812470
# 2015   8.553507   10.588599
# 2016  10.079706   10.176126
# 2017   9.299995   10.415373
# 2018   9.351991   10.377886

# %%
dataframe_monthly.to_csv('./data/dataframe_monthly.csv')
dataframe_yearly.to_csv('./data/dataframe_yearly.csv')
